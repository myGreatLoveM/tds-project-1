# %%
import numpy as np
import pandas as pd
import requests as r
import math

# %%
TOKEN = 'your_personal_access_token'

# %%
BASE_URL = "https://api.github.com"
HEADERS = {
    'Accept': 'application/vnd.github+json',
    'Authorization': f'Bearer {TOKEN}'
}

# %%
dublin_users = []
dublic_users_url = f"{BASE_URL}/search/users?q=location:Dublin+followers:>50"
total_dublin_users = 0
page = 1
per_page = 30

dublic_users_resp = r.get(dublic_users_url, headers=HEADERS)

if dublic_users_resp.status_code == 200:
  users = dublic_users_resp.json()
  dublin_users.extend(users['items'])
  if users['total_count'] > per_page:
    total_dublin_users = users['total_count']
    no_pages = math.ceil(total_dublin_users / per_page)
    page += 1

    while no_pages >= page:
      dublin_users_paginated_url = f"{dublic_users_url}&per_page={per_page}&page={page}"
      dublic_users_resp = r.get(dublin_users_paginated_url, headers=HEADERS)

      if dublic_users_resp.status_code == 200:
        users = dublic_users_resp.json()
        dublin_users.extend(users['items'])
      else:
        print(dublic_users_resp.status_code)
        break
      page += 1
else:
  print(dublic_users_resp.status_code)

# %%
dublin_users_url_df = pd.DataFrame(dublin_users, columns=['login', 'url'])

# %%
dublin_users_url_df.to_csv('dublin_users_url.csv')

# %%
users_data = []
users_repos = {}

for user_url in dublin_users_url_df['url']:
  resp = r.get(user_url, headers=HEADERS)

  if resp.status_code == 200:
    user_data = resp.json()
    users_data.append(user_data)
    page = 1
    per_page = 30
    total_public_repos = user_data['public_repos']
    if user_data['public_repos'] > 500:
      total_public_repos = 500
    no_pages = math.ceil(total_public_repos/per_page)

    while no_pages >= page:
      resp = r.get(f"{user_data['repos_url']}?sort=created_at&per_page={per_page}&page={page}", headers=HEADERS)

      if resp.status_code == 200:
        user_repos_data = resp.json()
        users_repos[user_data['login']] = user_repos_data
      else:
        print(resp.status_code)
        break
      page += 1
  else:
    print(resp.status_code)
    break

# %%
len(users_data)
# Out:
# 477

# %%
len(users_repos)
# Out:
# 470

# %%
users_df = pd.DataFrame(users_data, columns=['login', 'name', 'company', 'location', 'email', 'hireable', 'bio', 'public_repos', 'followers', 'following', 'created_at'])

# %%
for user in users_df['login']:
  if user not in users_repos:
    print(r.get(f"https://api.github.com/users/{user}", headers=HEADERS).json().get('public_repos'))
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
users_df.head()
# Out:
#                   login                    name  \
# 0                  orta             Orta Therox
# 1         jeromeetienne          Jerome Etienne
# 2            jonataslaw            Jonny Borges
# 3  steventroughtonsmith  Steven Troughton-Smith
# 4                  axic        Alex Beregszaszi
#
#                                     company  \
# 0                                      None
# 1                    Making WebAR a reality
# 2                                      Iris
# 3                     High Caffeine Content
# 4  @ethereum @ipsilon @spearbit @ethereumjs
#
#                                        location                     email  \
# 0  Huddersfield / NYC / Dublin / Rio de Janeiro               git@orta.io
# 1                               Dublin, Ireland  jerome.etienne@gmail.com
# 2                               Dublin, Ireland                      None
# 3                               Dublin, Ireland                      None
# 4                               Dublin, Ireland                      None
#
#   hireable                                                bio  public_repos  \
# 0     None  Tech on @puzzmo-com \r\n\r\nEx-TypeScript. Con...           952
# 1     True  Making WebAR a reality - Around Javascript and...           301
# 2     True  VP of Engineering from Iris Finance.\r\nDevelo...           272
# 3     None                                               None            98
# 4     True  Works on decentralised stuff.\r\n\r\neipnft:ax...           143
#
#    followers  following            created_at
# 0       6017        109  2009-01-24T20:40:31Z
# 1       2780         15  2010-04-26T11:58:29Z
# 2       2692         17  2018-01-23T19:17:15Z
# 3       1984          4  2009-01-08T23:51:31Z
# 4       1807          5  2008-08-11T23:38:10Z

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 477 entries, 0 to 476
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   login         477 non-null    object
#  1   name          470 non-null    object
#  2   company       315 non-null    object
#  3   location      477 non-null    object
#  4   email         235 non-null    object
#  5   hireable      182 non-null    object
#  6   bio           325 non-null    object
#  7   public_repos  477 non-null    int64
#  8   followers     477 non-null    int64
#  9   following     477 non-null    int64
#  10  created_at    477 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 41.1+ KB

# %%
users_df['created_at'] = pd.to_datetime(users_df['created_at'], format='%Y-%m-%dT%H:%M:%SZ')

# %%
users_df = users_df.fillna({
    'name': '',
    'company': '',
    'email': '',
    'hireable': '',
    'bio': ''
})

# %%
users_df['hireable'] = users_df['hireable'].replace({True: 'true', False: 'false'})

# %%
users_df['company'] = users_df['company'].apply(lambda x : x.strip().lstrip('@').upper())

# %%
users_df['bio'] = users_df['bio'].apply(lambda x: x.strip())

# %%
users_df.head()
# Out:
#                   login                    name  \
# 0                  orta             Orta Therox
# 1         jeromeetienne          Jerome Etienne
# 2            jonataslaw            Jonny Borges
# 3  steventroughtonsmith  Steven Troughton-Smith
# 4                  axic        Alex Beregszaszi
#
#                                    company  \
# 0
# 1                   MAKING WEBAR A REALITY
# 2                                     IRIS
# 3                    HIGH CAFFEINE CONTENT
# 4  ETHEREUM @IPSILON @SPEARBIT @ETHEREUMJS
#
#                                        location                     email  \
# 0  Huddersfield / NYC / Dublin / Rio de Janeiro               git@orta.io
# 1                               Dublin, Ireland  jerome.etienne@gmail.com
# 2                               Dublin, Ireland
# 3                               Dublin, Ireland
# 4                               Dublin, Ireland
#
#   hireable                                                bio  public_repos  \
# 0           Tech on @puzzmo-com \r\n\r\nEx-TypeScript. Con...           952
# 1     true  Making WebAR a reality - Around Javascript and...           301
# 2     true  VP of Engineering from Iris Finance.\r\nDevelo...           272
# 3                                                                        98
# 4     true  Works on decentralised stuff.\r\n\r\neipnft:ax...           143
#
#    followers  following          created_at  leader_strength
# 0       6017        109 2009-01-24 20:40:31        54.700000
# 1       2780         15 2010-04-26 11:58:29       173.750000
# 2       2692         17 2018-01-23 19:17:15       149.555556
# 3       1984          4 2009-01-08 23:51:31       396.800000
# 4       1807          5 2008-08-11 23:38:10       301.166667

# %%
users_df.to_csv('users.csv', index=False)

# %%
all_repos = []
for user in users_repos:
  for repo in users_repos[user]:
    repo_dict = {}
    repo_dict['login'] = repo.get('owner').get('login')
    repo_dict['full_name'] = repo.get('full_name')
    repo_dict['created_at'] = repo.get('created_at')
    repo_dict['stargazers_count'] = repo.get('stargazers_count')
    repo_dict['watchers_count'] = repo.get('watchers_count')
    repo_dict['language'] = repo.get('language')
    repo_dict['has_projects'] = repo.get('has_projects')
    repo_dict['has_wiki'] = repo.get('has_wiki')
    if repo.get('license') is None:
      repo_dict['license_name'] = None
    else:
      repo_dict['license_name'] = repo.get('license').get('name')

    all_repos.append(repo_dict)

# %%
len(all_repos)
# Out:
# 7208

# %%
total = 0
for user in users_repos:
  total += len(users_repos[user])

print(total)
# Out:
# 7208

# %%
repos_df = pd.DataFrame(all_repos)

# %%
repos_df.shape
# Out:
# (7208, 9)

# %%
repos_df.columns
# Out:
# Index(['login', 'full_name', 'created_at', 'stargazers_count',
#        'watchers_count', 'language', 'has_projects', 'has_wiki',
#        'license_name'],
#       dtype='object')

# %%
repos_df['created_at'] = pd.to_datetime(repos_df['created_at'], format='%Y-%m-%dT%H:%M:%SZ')

# %%
repos_df = repos_df.fillna({
    'language': '',
    'license_name': ''
})

# %%
repos_df['has_projects'] = repos_df['has_projects'].map({True: 'true', False: 'false'})

# %%
repos_df['has_wiki'] = repos_df['has_wiki'].map({True: 'true', False: 'false'})

# %%
repos_df
# Out:
#              login                             full_name          created_at  \
# 0             orta                          orta/typedoc 2017-04-08 17:00:09
# 1             orta                             orta/XVim 2017-04-07 15:25:16
# 2             orta            orta/jekyll-lunr-js-search 2017-04-05 07:02:28
# 3             orta                     orta/coffeelinter 2017-04-04 10:58:30
# 4             orta                          orta/json2ts 2017-03-30 10:46:49
# ...            ...                                   ...                 ...
# 7203  nakitamccool  nakitamccool/Travel-destinations-app 2017-02-03 11:10:36
# 7204  nakitamccool      nakitamccool/Positioning-and-CSS 2017-02-03 10:31:24
# 7205  nakitamccool                nakitamccool/BoxModel2 2017-02-03 10:22:20
# 7206  nakitamccool                nakitamccool/BoxModel1 2017-02-03 10:16:10
# 7207  nakitamccool                  nakitamccool/Gitster 2017-02-03 10:05:22
#
#       stargazers_count  watchers_count     language has_projects has_wiki  \
# 0                    0               0         HTML         true    false
# 1                    0               0  Objective-C         true     true
# 2                    0               0   JavaScript         true     true
# 3                    0               0   TypeScript         true     true
# 4                    1               1   TypeScript         true     true
# ...                ...             ...          ...          ...      ...
# 7203                 0               0   TypeScript         true     true
# 7204                 0               0         HTML         true     true
# 7205                 0               0         HTML         true     true
# 7206                 0               0         HTML         true     true
# 7207                 0               0   TypeScript         true     true
#
#             license_name
# 0     Apache License 2.0
# 1            MIT License
# 2            MIT License
# 3
# 4            MIT License
# ...                  ...
# 7203
# 7204
# 7205
# 7206
# 7207
#
# [7208 rows x 9 columns]

# %%
repos_df['has_projects'] = repos_df['has_projects'].astype(str)
repos_df['has_wiki'] = repos_df['has_wiki'].astype(str)

# %%
repos_df.to_csv('repositories.csv', index=False)

# %% [markdown]
# ### 1. Who are the top 5 users in Dublin with the highest number of followers? List their login in order, comma-separated.

# %%
users_df.sort_values(by='followers', ascending=False).head(5)
# Out:
#                   login                    name  \
# 0                  orta             Orta Therox
# 1         jeromeetienne          Jerome Etienne
# 2            jonataslaw            Jonny Borges
# 3  steventroughtonsmith  Steven Troughton-Smith
# 4                  axic        Alex Beregszaszi
#
#                                    company  \
# 0
# 1                   MAKING WEBAR A REALITY
# 2                                     IRIS
# 3                    HIGH CAFFEINE CONTENT
# 4  ETHEREUM @IPSILON @SPEARBIT @ETHEREUMJS
#
#                                        location                     email  \
# 0  Huddersfield / NYC / Dublin / Rio de Janeiro               git@orta.io
# 1                               Dublin, Ireland  jerome.etienne@gmail.com
# 2                               Dublin, Ireland
# 3                               Dublin, Ireland
# 4                               Dublin, Ireland
#
#   hireable                                                bio  public_repos  \
# 0           Tech on @puzzmo-com \r\n\r\nEx-TypeScript. Con...           952
# 1     true  Making WebAR a reality - Around Javascript and...           301
# 2     true  VP of Engineering from Iris Finance.\r\nDevelo...           272
# 3                                                                        98
# 4     true  Works on decentralised stuff.\r\n\r\neipnft:ax...           143
#
#    followers  following          created_at
# 0       6017        109 2009-01-24 20:40:31
# 1       2780         15 2010-04-26 11:58:29
# 2       2692         17 2018-01-23 19:17:15
# 3       1984          4 2009-01-08 23:51:31
# 4       1807          5 2008-08-11 23:38:10

# %% [markdown]
# ### 2. Who are the 5 earliest registered GitHub users in Dublin? List their login in ascending order of created_at, comma-separated.

# %%
users_df.sort_values(by='created_at', ascending=True).head()
# Out:
#           login           name      company         location  \
# 75       paulca  Paul Campbell         TITO  Dublin, Ireland
# 447      adrian   Adrian Smith      WORKDAY  Dublin, Ireland
# 85   GavinJoyce    Gavin Joyce         VIDU  Dublin, Ireland
# 74         amir  Amir M. Saeid               Dublin, Ireland
# 439   ciaranlee     Ciaran Lee  INTERCOM.IO  Dublin, Ireland
#
#                    email hireable  \
# 75         paul@rslw.com
# 447      adrian@17od.com
# 85
# 74   amirsaied@gmail.com     true
# 439
#
#                                                    bio  public_repos  \
# 75                                Founder of @teamtito           106
# 447                                                               52
# 85   Building vidu.io ✨. Previously, engineering In...           187
# 74                                                                82
# 439                                                               22
#
#      followers  following          created_at
# 75         213         20 2008-02-27 22:50:56
# 447         54         10 2008-02-29 20:03:31
# 85         191          8 2008-03-07 17:27:50
# 74         220        911 2008-04-02 18:46:51
# 439         55          5 2008-04-04 18:46:06

# %%
users_df.sort_values(by='created_at', ascending=True).head()['login'].unique()
# Out:
# array(['paulca', 'adrian', 'GavinJoyce', 'amir', 'ciaranlee'],
#       dtype=object)

# %% [markdown]
# ### 3. What are the 3 most popular license among these users? Ignore missing licenses. List the license_name in order, comma-separated.

# %%
repos_df['license_name'].value_counts().head()
# Out:
# license_name
#                                    4079
# MIT License                        1522
# Other                               484
# Apache License 2.0                  414
# GNU General Public License v3.0     264
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Which company do the majority of these developers work at?

# %%
users_df['company'].value_counts()
# Out:
# company
#                       162
# MICROSOFT              18
# AWS                    18
# GOOGLE                 16
# AMAZON                  8
#                      ...
# ADAPT CENTRE            1
# MECHANICAL ORCHARD      1
# DORSET COLLEGE          1
# TOMTOM                  1
# MASTERCARD              1
# Name: count, Length: 216, dtype: int64

# %% [markdown]
# ### 5. Which programming language is most popular among these users?

# %%
repos_df['language'].value_counts()
# Out:
# language
#                1209
# JavaScript     1114
# Python          911
# Java            533
# HTML            353
#                ...
# Solidity          1
# Cairo             1
# Mustache          1
# WebAssembly       1
# Standard ML       1
# Name: count, Length: 106, dtype: int64

# %% [markdown]
# ### 6. Which programming language is the second most popular among users who joined after 2020?

# %%
repos_df.loc[repos_df['login'].isin(users_df.loc[users_df['created_at'] > '2020-01-01', 'login']), 'language'].value_counts()

# %% [markdown]
# ### 7. Which language has the highest average number of stars per repository?

# %%
repos_df.groupby('language')['stargazers_count'].mean().sort_values(ascending=False)
# Out:
# language
# MDX           13042.000000
# CMake          2480.800000
# Vim Script      189.000000
# TypeScript      176.348259
# C               100.669421
#                   ...
# Lex               0.000000
# Scilab            0.000000
# Smali             0.000000
# Solidity          0.000000
# Nunjucks          0.000000
# Name: stargazers_count, Length: 106, dtype: float64

# %% [markdown]
# ### 8. Let's define leader_strength as followers / (1 + following). Who are the top 5 in terms of leader_strength? List their login in order, comma-separated

# %%
users_df['leader_strength'] = users_df['followers'] / (1 + users_df['following'])

# %%
list(users_df.sort_values(by='leader_strength', ascending=False).head()['login'].unique())
# Out:
# ['flaviohenriquealmeida', 'zalando', 'AnikSarker', 'wix', 'CardinalHealth']

# %%
users_df['company'].value_counts()
# Out:
# company
#                       162
# MICROSOFT              18
# AWS                    18
# GOOGLE                 16
# AMAZON                  8
#                      ...
# ADAPT CENTRE            1
# MECHANICAL ORCHARD      1
# DORSET COLLEGE          1
# TOMTOM                  1
# MASTERCARD              1
# Name: count, Length: 216, dtype: int64

# %% [markdown]
# ### 9. What is the correlation between the number of followers and the number of public repositories among users in Dublin?

# %%
users_df['followers'].corr(users_df['public_repos'], method='pearson')
# Out:
# 0.5547995009959515

# %% [markdown]
# ### 10. Does creating more repos help users get more followers? Using regression, estimate how many additional followers a user gets per additional public repository.

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(users_df[['public_repos']], users_df['followers'])
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([2.82481832])

# %%
# 11. Do people typically enable projects and wikis together? What is the correlation between a repo having projects enabled and having wiki enabled?

# %%
temp_df = repos_df[(repos_df['has_projects'] == 'true') & (repos_df['has_wiki'] == 'true')]

# %%
temp_df
# Out:
#              login                             full_name          created_at  \
# 1             orta                             orta/XVim 2017-04-07 15:25:16
# 2             orta            orta/jekyll-lunr-js-search 2017-04-05 07:02:28
# 3             orta                     orta/coffeelinter 2017-04-04 10:58:30
# 4             orta                          orta/json2ts 2017-03-30 10:46:49
# 6             orta                        orta/slack-api 2017-03-29 12:39:19
# ...            ...                                   ...                 ...
# 7203  nakitamccool  nakitamccool/Travel-destinations-app 2017-02-03 11:10:36
# 7204  nakitamccool      nakitamccool/Positioning-and-CSS 2017-02-03 10:31:24
# 7205  nakitamccool                nakitamccool/BoxModel2 2017-02-03 10:22:20
# 7206  nakitamccool                nakitamccool/BoxModel1 2017-02-03 10:16:10
# 7207  nakitamccool                  nakitamccool/Gitster 2017-02-03 10:05:22
#
#       stargazers_count  watchers_count     language has_projects has_wiki  \
# 1                    0               0  Objective-C         true     true
# 2                    0               0   JavaScript         true     true
# 3                    0               0   TypeScript         true     true
# 4                    1               1   TypeScript         true     true
# 6                    0               0   JavaScript         true     true
# ...                ...             ...          ...          ...      ...
# 7203                 0               0   TypeScript         true     true
# 7204                 0               0         HTML         true     true
# 7205                 0               0         HTML         true     true
# 7206                 0               0         HTML         true     true
# 7207                 0               0   TypeScript         true     true
#
#      license_name
# 1     MIT License
# 2     MIT License
# 3
# 4     MIT License
# 6     MIT License
# ...           ...
# 7203
# 7204
# 7205
# 7206
# 7207
#
# [6336 rows x 9 columns]

# %%
temp_df['has_projects'].corr(temp_df['has_wiki'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-201-cd10ac773277> in <cell line: 1>()
# ----> 1 temp_df['has_projects'].corr(temp_df['has_wiki'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2971             return np.nan
#    2972
# -> 2973         this_values = this.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    2974         other_values = other.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    2975
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in to_numpy(self, dtype, copy, na_value, **kwargs)
#     660             values[np.asanyarray(isna(self))] = na_value
#     661
# --> 662         result = np.asarray(values, dtype=dtype)
#     663
#     664         if (copy and not fillna) or (not copy and using_copy_on_write()):
#
# ValueError: could not convert string to float: 'true'

# %% [markdown]
# ### 12. Do hireable users follow more people than those who are not hireable?

# %%
users_df.loc[users_df['hireable'] != 'true', 'following'].mean()
# Out:
# 65.52881355932203

# %%
users_df.loc[users_df['hireable'] == 'true', 'following'].mean()
# Out:
# 112.81318681318682

# %%
112.813186813186822 - 65.52881355932203
# Out:
# 47.284373253864786

# %% [markdown]
# ### 13. Some developers write long bios. Does that help them get more followers? What's the impact of the length of their bio (in Unicode words, split by whitespace) with followers? (Ignore people without bios)?

# %%
lr.fit(users_df.loc[users_df['bio'] != '', 'bio'].str.strip().str.split().str.len().to_frame(), users_df.loc[users_df['bio'] != '', 'followers'].to_frame())
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([[7.23892787]])

# %%
users_df.loc[users_df['bio'] != '', 'bio'].str.strip().str.split().str.len().to_frame()
# Out:
#      bio
# 0     16
# 1     22
# 2     15
# 4      5
# 5     13
# ..   ...
# 470    5
# 471   22
# 472    7
# 474    8
# 475    3
#
# [325 rows x 1 columns]

# %%
repos_df['weekday'] = repos_df['created_at'].apply(lambda x: x.weekday())

# %%
repos_df.loc[repos_df['weekday'].isin([5, 6]), 'login'].value_counts().head(12)
# Out:
# login
# hmikihth         24
# joshuacassidy    18
# 10xOXR           16
# yumin-chen       15
# sakrist          15
# SibeeshVenu      15
# ocanty           15
# gdyrrahitis      13
# prakhargurawa    13
# nhtlongcs        13
# Thrifleganger    13
# eddieantonio     13
# Name: count, dtype: int64

# %% [markdown]
# ### 15. Do people who are hireable share their email addresses more often?

# %%
users_df[(users_df['email'] != '') & (users_df['hireable'] == 'true')].shape[0] / users_df.shape[0]
# Out:
# 0.2138364779874214

# %%
users_df[(users_df['email'] != '') & (users_df['hireable'] != 'true')].shape[0] / users_df.shape[0]
# Out:
# 0.27882599580712786

# %%
round(0.2138364779874214 - 0.27882599580712786, ndigits=3)
# Out:
# -0.065

# %% [markdown]
# ### 16. Let's assume that the last word in a user's name is their surname (ignore missing names, trim and split by whitespace.) What's the most common surname? (If there's a tie, list them all, comma-separated, alphabetically)

# %%
users_df['name'].apply(lambda x : x.split()[1] if len(x.split()) == 2 else None).value_counts().head()
# Out:
# name
# Quinn         3
# Chen          3
# O'Sullivan    3
# Kenny         3
# Müller        2
# Name: count, dtype: int64
